# %% [markdown]
# ### Plot by label (Signal vs Pile-up)
# ### Plot multiple pulses (either as a grid or on the same plot)
# ### Plot average pulse (either label)
# ### Timing parameters to show differences between two classes (e.g., rise time)
# ### Distributions of parameters for both labels to show overlap
# ### Energy distribution of all pulses vs clean pulses to show differences in resolution
# ### Data properties such as shape, data type
# ### Preparation of pytorch datasets
